# %%
import sys
import os

# Add project root to Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt

from scripts.data_cleaning import clean_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 from scripts.data_cleaning import clean_data
#
# ImportError: cannot import name 'clean_data' from 'scripts.data_cleaning' (C:\Users\ranas\data analytics\scripts\data_cleaning.py)

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

# %%
import pandas as pd
import matplotlib.pyplot as plt

from scripts.data_cleaning import clean_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 from scripts.data_cleaning import clean_data
#
# ImportError: cannot import name 'clean_data' from 'scripts.data_cleaning' (C:\Users\ranas\data analytics\scripts\data_cleaning.py)

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

import scripts.data_cleaning as dc
print(dir(dc))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
import pandas as pd
import matplotlib.pyplot as plt

from scripts.data_cleaning import clean_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 from scripts.data_cleaning import clean_data
#
# ImportError: cannot import name 'clean_data' from 'scripts.data_cleaning' (C:\Users\ranas\data analytics\scripts\data_cleaning.py)

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)

import scripts.data_cleaning as dc
print(dir(dc))
# Out:
# ['__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__']

# %%
from scripts.data_cleaning import clean_data
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 from scripts.data_cleaning import clean_data
#
# ImportError: cannot import name 'clean_data' from 'scripts.data_cleaning' (C:\Users\ranas\data analytics\scripts\data_cleaning.py)

# %%
from scripts.data_cleaning import clean_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from scripts.data_cleaning import clean_data
#
# ModuleNotFoundError: No module named 'scripts'

# %%
import sys
import os

# HARD-CODE project root (safe & clear)
project_root = r"C:\Users\ranas\data analytics"
sys.path.insert(0, project_root)

print(project_root)
# Out:
# C:\Users\ranas\data analytics

# %%
from scripts.data_cleaning import clean_data

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = clean_data("data/sales_data.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 df = clean_data("data/sales_data.csv")
#       5 df.head()
#
# File ~\data analytics\scripts\data_cleaning.py:4, in clean_data(csv_path)
#       3 def clean_data(csv_path):
# ----> 4     df = pd.read_csv(csv_path)
#       6     df["order_date"] = pd.to_datetime(df["order_date"])
#       7     df = df.drop_duplicates()
#
# File c:\Users\ranas\data analytics\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\ranas\data analytics\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\ranas\data analytics\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\ranas\data analytics\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\ranas\data analytics\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/sales_data.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = clean_data("../data/sales_data.csv")
df.head()
# Out:
#    order_id product     category  price  quantity order_date  total_sales
# 0         1  Laptop  Electronics  60000         1 2024-01-05        60000
# 1         2   Mouse  Electronics    800         2 2024-01-10         1600
# 2         3   Chair    Furniture   4500         1 2024-02-15         4500
# 3         4   Table    Furniture   7000         1 2024-02-18         7000
# 4         5   Phone  Electronics  30000         1 2024-03-01        30000

# %%
category_sales = df.groupby("category")["total_sales"].sum()

category_sales.plot(kind="bar")
plt.title("Revenue by Category")
plt.xlabel("Category")
plt.ylabel("Revenue")
plt.show()

# %%
df["month"] = df["order_date"].dt.to_period("M")

monthly_sales = df.groupby("month")["total_sales"].sum()

monthly_sales.plot(kind="line", marker="o")
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.show()

# %%
print("Total Revenue:", df["total_sales"].sum())
print("Average Order Value:", round(df["total_sales"].mean(), 2))
print("Total Orders:", df["order_id"].nunique())
# Out:
# Total Revenue: 141600
# Average Order Value: 17700.0
# Total Orders: 8
